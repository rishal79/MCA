# %%
import matplotlib.pyplot as plt

temp=[12,14,16,18,20,22,24]
celsius=[100,200,250,400,300,450,500]

plt.plot(temp,celsius,marker='o')
plt.xlabel("Temp")
plt.ylabel("Celsius")
plt.title("temp vs celsius")
plt.show()
