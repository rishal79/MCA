# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %%
# Cell 2: Create a custom dataset
# Features: [study_hours, sleep_hours]
X = [
    [2, 9],  # studied 2 hrs, slept 9 hrs -> Fail
    [1, 6],
    [3, 7],
    [5, 5],
    [6, 6],
    [7, 3],
    [8, 4],
    [9, 2]
]

# Labels: 0 = Fail, 1 = Pass
y = [0, 0, 0, 1, 1, 1, 1, 1]

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=42)

# %%
knn=KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_pred=knn.predict(X_test)
print("Accuracy:",accuracy_score(y_test,y_pred))
# Out:
# Accuracy: 1.0

# %%
new_student=[[3,6]]
prediction=knn.predict(new_student)
print("prediction for new student:", "pass" if prediction[0]==1 else "fail")
# Out:
# prediction for new student: pass

# %%
# Import libraries
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# Dataset: [weight, texture]
# texture: 0 = Smooth, 1 = Rough
X = [
    [150, 0],  # Apple
    [170, 0],  # Apple
    [140, 0],  # Apple
    [130, 0],  # Apple
    [180, 1],  # Orange
    [160, 1],  # Orange
    [200, 1],  # Orange
    [210, 1]   # Orange
]

# Labels: 0 = Apple, 1 = Orange
y = [0, 0, 0, 0, 1, 1, 1, 1]

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# Train k-NN model
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train, y_train)

# Accuracy
y_pred = knn.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))

# Predict a new fruit
new_fruit = [[155, 0]]  # 155g and smooth texture
prediction = knn.predict(new_fruit)
print("Prediction for new fruit:", "Orange" if prediction[0] == 1 else "Apple")
# Out:
# Accuracy: 0.5
# Prediction for new fruit: Apple

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

X=[
  [8,5],
    [3,7],
    [3,6],
    [7,3]
    
]
y=[0,1,2,0]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
knn = KNeighborsClassifier(n_neighbors=3)

knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))

new_fruit = [[6, 4]]
prediction = knn.predict(new_fruit)
if prediction[0] == 0:
    print("Prediction for new item: Apple")
elif prediction[0] == 1:
    print("Prediction for new item: Orange")
elif prediction[0] == 2:
    print("Prediction for new item: Chicken")
else:
    print("Unknown prediction")
# Out:
# Accuracy: 0.0
# Prediction for new item: Apple

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
import pandas as pd

df = pd.read_csv('dataset.csv')


print(df)
df = pd.read_csv('dataset.csv')
X=df['Sweetness']
# Out:
#    Ingredient  Sweetness  Crunchiness  Food type
# 0       grape          8            5      fruit
# 1  green bean          3            7  vegetable
# 2        nuts          3            6    protein
# 3      orange          7            3      fruit
# 0    8
# 1    3
# 2    3
# 3    7
# Name: Sweetness, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
import pandas as pd

df = pd.read_csv('dataset.csv')
X=df[['Sweetness','Crunchiness']]
y=df['Food type']


X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.25, random_state=42)
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))

new_fruit = [[6, 4]]
prediction = knn.predict(new_fruit)
if prediction[0] == "fruit":
    print("Prediction for new item: fruit")
elif prediction[0] == "vegetable":
    print("Prediction for new item: vegetable")
elif prediction[0] == "protein":
    print("Prediction for new item: protein")
else:
    print("Unknown prediction")
# Out:
# Accuracy: 0.0
# Prediction for new item: fruit

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
import numpy as np

df = pd.read_csv('dataset.csv')
X=df[['Sweetness','Crunchiness']]
y=df['Food type']


X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.25, random_state=42)
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))

# new_fruit = int(input("enter Sweetness and Crunchiness").split())
#np.array(new_fruit)
# prediction = knn.predict(np.array(new_fruit).reshape(1, -1))

#print(prediction)

# user_input = input("Enter Sweetness and Crunchiness separated by space (e.g. '6 4'): ")

# Split and convert to ints
# new_fruit = [int(x) for x in user_input.split()]

# Make 2D array for prediction (1 sample, 2 features)
# new_fruit_array = np.array(new_fruit).reshape(1, -1)

# Predict
# prediction = knn.predict(new_fruit_array)

print("Prediction:", prediction)
# Out:
# Accuracy: 0.0
# enter Sweetness and Crunchiness5 6
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\AWH10~1\AppData\Local\Temp/ipykernel_5244/410085228.py in <module>
#      15 print("Accuracy:", accuracy_score(y_test, y_pred))
#      16
# ---> 17 new_fruit = int(input("enter Sweetness and Crunchiness").split())
#      18 #np.array(new_fruit)
#      19 prediction = knn.predict(np.array(new_fruit).reshape(1, -1))
#
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'list'
